# %%
from sklearn.datasets import load_diabetes
from sklearn.metrics import r2_score
import numpy as np

# %%
X,y=load_diabetes(return_X_y=True)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=8)

# %%
from sklearn.linear_model import Ridge

# %%
reg=Ridge(alpha=0.1,solver='cholesky') # cholesky is used for solve ridge regression equation( decomposition)

# %%
reg.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.1, solver='cholesky')

# %%
y_pred=reg.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.5084848618579592

# %%
print(reg.coef_)
print(reg.intercept_)
# Out:
# [  10.69701078 -222.96079138  485.22087485  336.2378122  -116.95612501
#   -80.05543351 -200.07528232  133.46298072  380.36946417  123.62671575]
# 152.06924932618526

# %%
class Meraridge:
    def __init__(self,alpha=0.1):
        self.alpha=alpha
        self.coef_=None
        self.intercept_=None
    def fit(self,x_train,y_train):
        x_train=np.insert(x_train,0,1,axis=1)
        I=np.identity(x_train.shape[1])
        I[0][0]=0
        result=np.linalg.inv(np.dot(x_train.T,x_train)+self.alpha*I).dot(x_train.T).dot(y_train)
        self.intercept_=result[0]
        self.coef_=result[1:]
    def predict(slf,x_test):
        return np.dot(x_test,self.coef_)+self.intercept_

# %%
reg=Meraridge()

# %%
reg.fit(x_train,y_train)
y_pred=reg.predict(x_test)
print(r2_score(y_test,y_pred))
print(reg.coef_)
print(reg.intercept_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 reg.fit(x_train,y_train)
# ----> 2 y_pred=reg.predict(x_test)
#       3 print(r2_score(y_test,y_pred))
#       4 print(reg.coef_)
#
# Cell In[33], line 14, in Meraridge.predict(slef, x_test)
#      13 def predict(slef,x_test):
# ---> 14     return np.dot(x_test,self.coef_)+self.intercept_
#
# NameError: name 'self' is not defined
