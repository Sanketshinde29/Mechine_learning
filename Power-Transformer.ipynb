# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# It is used for ploting normal distribution plot/graph
import scipy.stats as stats

# %%
df=pd.read_csv("C:/Users/sanke/Downloads/concrete_data.csv")

# %%
df.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

from sklearn.linear_model import LinearRegression

from sklearn.metrics import r2_score

from sklearn.preprocessing import PowerTransformer

# %%
df.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
df.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
x = df.drop(columns=['Strength'])
y = df.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=43)

# %%
# Applying Regression without any transformation

lr=LinearRegression()
lr.fit(x_train,y_train)

y_pred=lr.predict(x_test)

r2_score(y_test,y_pred)
# Out:
# 0.6047992508809408

# %%
# cross checking with cross val score
lr = LinearRegression()
np.mean(cross_val_score(lr,x,y,scoring='r2'))
# Out:
# 0.4609940491662862

# %%
# Plotting dist plot without transformation

for col in x_train.columns:
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    sns.distplot(x_train[col])
    plt.title(col)
    
    plt.subplot(122)
    stats.probplot(x_train[col],dist='norm',plot=plt)
    plt.title(col)
    plt.show()
# Out:
# C:\Users\sanke\AppData\Local\Temp\ipykernel_19288\3422872055.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x_train[col])
# C:\Users\sanke\AppData\Local\Temp\ipykernel_19288\3422872055.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x_train[col])
# C:\Users\sanke\AppData\Local\Temp\ipykernel_19288\3422872055.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x_train[col])
# C:\Users\sanke\AppData\Local\Temp\ipykernel_19288\3422872055.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x_train[col])
# C:\Users\sanke\AppData\Local\Temp\ipykernel_19288\3422872055.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x_train[col])
# C:\Users\sanke\AppData\Local\Temp\ipykernel_19288\3422872055.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x_train[col])
# C:\Users\sanke\AppData\Local\Temp\ipykernel_19288\3422872055.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x_train[col])
# C:\Users\sanke\AppData\Local\Temp\ipykernel_19288\3422872055.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x_train[col])

# %%
# Appling Box-Cox Transform

pt=PowerTransformer(method='box-cox')

x_train_transformed = pt.fit_transform(x_train+0.00001)
x_test_transformed = pt.transform(x_test+0.00001)

print(r2_score(y_test,y_pred))
pd.DataFrame({'cols':x_train.columns,'box_cox_lambda':pt.lambdas_})
# Out:
# 0.6047992508809408
#                  cols  box_cox_lambda
# 0              Cement        0.172067
# 1  Blast Furnace Slag        0.026321
# 2             Fly Ash       -0.043616
# 3               Water        0.838273
# 4    Superplasticizer        0.105062
# 5    Coarse Aggregate        0.960603
# 6      Fine Aggregate        1.792756
# 7                 Age        0.045467

# %%
# Appling linear regression on transformed data
lr= LinearRegression()
lr.fit(x_train_transformed,y_train)

y_pred2=lr.predict(x_test_transformed)

r2_score(y_test,y_pred2)
# Out:
# 0.7866072068329917

# %%
# Using cross val score
pt = PowerTransformer(method='box-cox')
x_transformed=pt.fit_transform(x+0.000001)

lr=LinearRegression()
np.mean(cross_val_score(lr,x_transformed,y,scoring='r2'))
# Out:
# 0.6662950324463972

# %%
# Apply Yeo-Jhonson transform

pt1 = PowerTransformer()

x_train_transformed2=pt1.fit_transform(x_train)
x_test_transformed2=pt1.transform(x_test)

lr = LinearRegression()
lr.fit(x_train_transformed2,y_train)

y_pred3=lr.predict(x_test_transformed2)

print(r2_score(y_test,y_pred3))

pd.DataFrame({'cols':x_train.columns,'Yeo_Johnson_lambdas':pt1.lambdas_})
# Out:
# 0.7860898212918341
#                  cols  Yeo_Johnson_lambdas
# 0              Cement             0.169302
# 1  Blast Furnace Slag             0.015905
# 2             Fly Ash            -0.157598
# 3               Water             0.837278
# 4    Superplasticizer             0.237077
# 5    Coarse Aggregate             0.960656
# 6      Fine Aggregate             1.793856
# 7                 Age            -0.000926

# %%
# Appling cross val score
pt= PowerTransformer()
x_transformed2=pt.fit_transform(x)
lr=LinearRegression()
np.mean(cross_val_score(lr,x_))
