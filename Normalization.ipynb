# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/sanke/Downloads/wine_data (1).csv",header=None,usecols=[0,1,2])
df.columns=['Class label','Alcohol','Malic acid']
df
# Out:
#      Class label  Alcohol  Malic acid
# 0              1    14.23        1.71
# 1              1    13.20        1.78
# 2              1    13.16        2.36
# 3              1    14.37        1.95
# 4              1    13.24        2.59
# ..           ...      ...         ...
# 173            3    13.71        5.65
# 174            3    13.40        3.91
# 175            3    13.27        4.28
# 176            3    13.17        2.59
# 177            3    14.13        4.10
#
# [178 rows x 3 columns]

# %%
sns.kdeplot(df['Alcohol'])
# Out:
# <Axes: xlabel='Alcohol', ylabel='Density'>

# %%
print(df.dtypes)
# Out:
# Class label      int64
# Alcohol        float64
# Malic acid     float64
# dtype: object

# %%
sns.kdeplot(df['Malic acid'])
# Out:
# <Axes: xlabel='Malic acid', ylabel='Density'>

# %%
import seaborn as sns

color_dict = {1: 'red', 2: 'blue', 3: 'green'}

sns.scatterplot(
    x='Alcohol',
    y='Malic acid',
    hue='Class label',
    data=df,
    palette=color_dict
)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malic acid'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df.drop('Class label',axis=1),df['Class label'],test_size=0.3,random_state=0)
x_train.shape,x_test.shape
# Out:
# ((124, 2), (54, 2))

# %%
from sklearn.preprocessing import MinMaxScaler # min-max provide between 0-1 value in min and max

scaler = MinMaxScaler()

# fit the scaler to the train set, it will learn the parameters
scaler.fit(x_train)

# transform train and test sets
x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_train_scaled = pd.DataFrame(x_train_scaled, columns=x_train.columns)
x_test_scaled = pd.DataFrame(x_test_scaled, columns=x_test.columns)

# %%
np.round(x_train.describe(),1)
# Out:
#        Alcohol  Malic acid
# count    124.0       124.0
# mean      13.0         2.4
# std        0.8         1.1
# min       11.0         0.9
# 25%       12.4         1.6
# 50%       13.0         1.9
# 75%       13.6         3.2
# max       14.8         5.6

# %%
np.round(x_train_scaled.describe(),1)
# Out:
#        Alcohol  Malic acid
# count    124.0       124.0
# mean       0.5         0.3
# std        0.2         0.2
# min        0.0         0.0
# 25%        0.4         0.2
# 50%        0.5         0.2
# 75%        0.7         0.5
# max        1.0         1.0

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df.drop('Class label',axis=1),df['Class label'],test_size=0.3,random_state=0)

# %%
x_train.shape,x_test.shape
# Out:
# ((124, 2), (54, 2))

# %%
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()
scaler.fit(x_train)
# Out:
# RobustScaler()

# %%
x_train_scaler=scaler.transform(x_train)
x_test_scaler=scaler.transform(x_test)

# %%
x_train_scaled=pd.DataFrame(x_train_scaler,columns=x_train.columns)
x_test_scaled=pd.DataFrame(x_test_scaler,columns=x_test.columns)

# %%
np.round(x_train_scaled.describe(),1)
# Out:
#        Alcohol  Malic acid
# count    124.0       124.0
# mean      -0.0         0.3
# std        0.6         0.7
# min       -1.6        -0.6
# 25%       -0.5        -0.2
# 50%        0.0         0.0
# 75%        0.5         0.8
# max        1.3         2.3

# %%
np.round(x_train.describe(),1)
# Out:
#        Alcohol  Malic acid
# count    124.0       124.0
# mean      13.0         2.4
# std        0.8         1.1
# min       11.0         0.9
# 25%       12.4         1.6
# 50%       13.0         1.9
# 75%       13.6         3.2
# max       14.8         5.6
