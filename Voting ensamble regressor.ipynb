# %%
import pandas as pd
import numpy as np

data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
x = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
y = raw_df.values[1::2, 2]
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\sanke\AppData\Local\Temp\ipykernel_20952\4127038542.py:5: SyntaxWarning: invalid escape sequence '\s'
#   raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)

# %%
x.shape
# Out:
# (506, 13)

# %%
y.shape
# Out:
# (506,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score

# %%
lr=LinearRegression()
dt=DecisionTreeRegressor()
svr=SVR()

# %%
estimators=[('lr',lr),('dt',dt),('svr',svr)]

# %%
for estimator in estimators:
    scores=cross_val_score(estimator[1],x,y,scoring='r2',cv=10)
    print(estimator[0],np.round(np.mean(scores),2))
# Out:
# lr 0.2
# dt -0.17
# svr -0.41

# %%
from sklearn.ensemble import VotingRegressor

# %%
vr = VotingRegressor(estimators)
scores=cross_val_score(vr,x,y,scoring='r2',cv=10)
print("Voting regressor",np.round(np.mean(scores),2))
# Out:
# Voting regressor 0.44

# %%
for i in range(1,4):
    for j in range(1,4):
        for k in range(1,4):
            vr = VotingRegressor(estimators,weights=[i,j,k])
            scores=cross_val_score(vr,x,y,scoring='r2',cv=10)
            print("For i={},j={},k={}".format(i,j,k),np.round(np.mean(scores),2))
# Out:
# For i=1,j=1,k=1 0.44
# For i=1,j=1,k=2 0.35
# For i=1,j=1,k=3 0.26
# For i=1,j=2,k=1 0.41
# For i=1,j=2,k=2 0.38
# For i=1,j=2,k=3 0.31
# For i=1,j=3,k=1 0.38
# For i=1,j=3,k=2 0.4
# For i=1,j=3,k=3 0.37
# For i=2,j=1,k=1 0.43
# For i=2,j=1,k=2 0.42
# For i=2,j=1,k=3 0.35
# For i=2,j=2,k=1 0.45
# For i=2,j=2,k=2 0.38
# For i=2,j=2,k=3 0.4
# For i=2,j=3,k=1 0.41
# For i=2,j=3,k=2 0.45
# For i=2,j=3,k=3 0.39
# For i=3,j=1,k=1 0.41
# For i=3,j=1,k=2 0.43
# For i=3,j=1,k=3 0.37
# For i=3,j=2,k=1 0.45
# For i=3,j=2,k=2 0.48
# For i=3,j=2,k=3 0.42
# For i=3,j=3,k=1 0.43
# For i=3,j=3,k=2 0.45
# For i=3,j=3,k=3 0.45

# %%
# Using same algorithm

dt1=DecisionTreeRegressor(max_depth=1)
dt2=DecisionTreeRegressor(max_depth=3)
dt3=DecisionTreeRegressor(max_depth=5)
dt4=DecisionTreeRegressor(max_depth=7)
dt5=DecisionTreeRegressor(max_depth=None)

# %%
estimators=[("dt1",dt1),("dt2",dt2),("dt3",dt3),("dt4",dt4),("dt5",dt5)]

# %%
for estimator in estimators:
    scores=cross_val_score(estimator[1],x,y,scoring='r2',cv=10)
    print(estimator[0],np,round(np.mean(scores),2))
# Out:
# dt1 <module 'numpy' from 'C:\\Users\\sanke\\AppData\\Roaming\\Python\\Python312\\site-packages\\numpy\\__init__.py'> -0.85
# dt2 <module 'numpy' from 'C:\\Users\\sanke\\AppData\\Roaming\\Python\\Python312\\site-packages\\numpy\\__init__.py'> -0.11
# dt3 <module 'numpy' from 'C:\\Users\\sanke\\AppData\\Roaming\\Python\\Python312\\site-packages\\numpy\\__init__.py'> -0.05
# dt4 <module 'numpy' from 'C:\\Users\\sanke\\AppData\\Roaming\\Python\\Python312\\site-packages\\numpy\\__init__.py'> 0.08
# dt5 <module 'numpy' from 'C:\\Users\\sanke\\AppData\\Roaming\\Python\\Python312\\site-packages\\numpy\\__init__.py'> -0.21

# %%
vr = VotingRegressor(estimators)
scores = cross_val_score(vr,x,y,scoring='r2',cv=10)
print("Voting Regressor",np.round(np.mean(scores),2))
# Out:
# Voting Regressor 0.2
